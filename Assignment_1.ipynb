# %% [markdown]
# <a href="https://colab.research.google.com/github/Riya-Sharma82/Cognitive-Assignment-/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Assignmet 1
name = "Riya Sharma"
for i in range(3):
    print(name)

#Assignment 2.1
a = 5
b = 10
c = 15
sum = a + b + c
print("Sum =", sum)

#Assignment 2.2
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")
str3 = input("Enter third string: ")
result = str1 + str2 + str3
print("Concatenated String:", result)

#Assignment4.1
for i in range(1, 11):
    print("7 x",i, "=", 7*i)
print()
for i in range(1, 11):
    print("9 x",i, "=", 9*i)

#Assignment4.2
n = int(input())
for i in range(1, 11):
    print(n, "x", i, "=", n*i)

#Assignment 4.3
n = int(input())
s = 0
for i in range(1, n+1):
    s = s + i
print(s)

#Assignment5.1
a = int(input())
b = int(input())
c = int(input())
m = max(a, b, c)
print(m)

#Assignment 5.2
n = int(input())
s = 0
for i in range(1, n+1):
    if i % 7 == 0 and i % 9 == 0:
        s = s + i
print(s)
#Assignment 5.3
n = int(input())
s = 0
for i in range(2, n+1):
    is_prime = True
    for j in range(2, i):
        if i % j == 0:
            is_prime = False
            break
    if is_prime:
        s = s + i
print(s)
#Assignemt6.1
def sum_odd(n):
    s = 0
    for i in range(1, n+1):
        if i % 2 != 0:
            s = s + i
    return s
n = int(input())
print(sum_odd(n))
#Assigment6.2
def sum_prime(n):
    s = 0
    for i in range(2, n+1):
        is_prime = True
        for j in range(2, i):
            if i % j == 0:
                is_prime = False
                break
        if is_prime:
            s = s + i
    return s
n = int(input())
print(sum_prime(n))
